# %%
with open('../training-set/dataset_1593.xyz','r') as f:
    xyz_data=f.readlines()

# %%
xyz_data
# Out:
# ['192\n',
#  'TotEnergy=-1103.24236000 cutoff=-1.00000000 nneightol=1.20000000 pbc="T T T" Lattice="23.46511000       0.00000000       0.00000000      -0.00000100      23.46511000       0.00000000      -0.00000100      -0.00000100      23.46511000" Properties=species:S:1:pos:R:3:force:R:3:Z:I:1\n',
#  'O              11.72590000     14.59020000     25.33440000     -0.04213780      0.03788820      0.00314949       8\n',
#  'H              12.69400000     16.13880000     24.72010000     -0.03709700     -0.03453660      0.01566490       1\n',
#  'H               9.70021000     15.03790000     25.76530000      0.07676920     -0.00101183     -0.02270490       1\n',
#  'O              10.68010000      3.41217000      4.43292000     -0.01918440      0.01516070      0.03966070       8\n',
#  'H              10.14500000      3.90822000      6.40047000      0.01092440     -0.00643783     -0.08715890       1\n',
# ...

# %%
with open("./out6.lammpstrj",'r') as f:
    lammps_data=f.readlines()

# %%
lammps_data
# Out:
# ['ITEM: TIMESTEP\n',
#  '0\n',
#  'ITEM: NUMBER OF ATOMS\n',
#  '192\n',
#  'ITEM: BOX BOUNDS pp pp pp\n',
#  '0.0000000000000000e+00 4.6936999999999998e+01\n',
#  '0.0000000000000000e+00 4.4121000000000002e+01\n',
#  '0.0000000000000000e+00 4.5182000000000002e+01\n',
#  'ITEM: ATOMS element x y z \n',
#  'O 1.37 1.8 3.37 \n',
#  'H 0.46 1.45 3.4 \n',
#  'H 1.77 1.46 4.15 \n',
#  'O 5.3 4.59 1.08 \n',
#  'H 4.4 4.86 1.07 \n',
#  'H 5.26 3.61 1.07 \n',
#  'O 6.48 5.45 3.37 \n',
#  'H 7.4 5.14 3.34 \n',
#  'H 6.09 5.12 2.58 \n',
#  'O 5.23 4.46 5.64 \n',
#  'H 5.71 4.81 6.37 \n',
#  'H 5.69 4.8 4.86 \n',
#  'O 2.55 0.88 5.65 \n',
#  'H 3.47 1.17 5.65 \n',
#  'H 2.6 44.061 5.64 \n',
#  'O 2.59 5.55 5.7 \n',
#  'H 3.49 5.19 5.67 \n',
#  'H 2.18 5.22 4.91 \n',
#  'O 5.3 1.78 1.11 \n',
#  'H 4.38 1.44 1.08 \n',
#  'H 5.69 1.46 0.33 \n',
#  'O 5.25 1.71 5.6 \n',
#  'H 5.27 2.69 5.63 \n',
#  'H 5.68 1.44 6.38 \n',
#  'O 1.31 4.56 7.95 \n',
#  'H 1.77 4.87 7.14 \n',
#  'H 1.34 3.62 7.89 \n',
# ...
