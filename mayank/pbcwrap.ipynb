# %%
from ase import io
xyz=io.read('../training-set/dataset_1593.xyz',index=":")

# %%
for frame in xyz:
    #print(frame)
    #print(frame.cell[0][0])
    #frame.set_cell([frame.cell[0][0],frame.cell[1][1],frame.cell[2][2]])
    frame.set_cell(frame.cell)
    frame.set_pbc([True,True,True])
    frame.wrap()
# io.xyz.write_xyz('trajectory_wrapped.xyz',xyz)
for i in xyz[0]:
    print(i)
# Out:
# Atom('O', [11.7259, 14.590200000000001, 1.8692900000000012], index=0)
# Atom('H', [12.694000000000003, 16.1388, 1.254989999999998], index=1)
# Atom('H', [9.70021, 15.0379, 2.300190000000003], index=2)
# Atom('O', [10.6801, 3.41217, 4.43292], index=3)
# Atom('H', [10.145, 3.90822, 6.40047], index=4)
# Atom('H', [9.97507, 4.53606, 3.00742], index=5)
# Atom('O', [22.18274, 20.6693, 0.33214], index=6)
# Atom('H', [21.46423, 19.4432, 1.5355999999999999], index=7)
# Atom('H', [21.84882, 22.603, 0.504982], index=8)
# Atom('O', [9.21461, 6.250880000000001, 0.4878900000000027], index=9)
# Atom('H', [10.6101, 7.50972, 23.3634], index=10)
# Atom('H', [7.77751, 7.224260000000001, 23.3005], index=11)
# Atom('O', [16.8951, 17.3288, 12.2373], index=12)
# Atom('H', [15.9395, 18.6919, 12.7173], index=13)
# Atom('H', [16.0391, 15.8326, 12.6528], index=14)
# Atom('O', [15.258300000000002, 4.21441, 0.24998999999999943], index=15)
# Atom('H', [15.2409, 5.27627, 1.8364900000000013], index=16)
# ...
