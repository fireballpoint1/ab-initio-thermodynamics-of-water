# %%
from ase import Atoms
data=[]
with open('./data/out_unbiased5.xyz','r') as f:
    data=f.readlines()

# %%
data
# Out:
# ['192\n',
#  'Atoms. Timestep: 0\n',
#  '2 6.203 7.71822 0.9847\n',
#  '1 6.71513 8.53743 0.6597\n',
#  '1 5.13141 7.95505 1.2126\n',
#  '2 5.64977 1.80504 2.34501\n',
#  '1 5.3667 2.06745 3.38585\n',
#  '1 5.27681 2.39958 1.59093\n',
#  '2 11.7388 10.9341 0.175702\n',
#  '1 11.3587 10.2855 0.812332\n',
#  '1 11.5622 11.957 0.267135\n',
#  '2 4.87453 3.30672 0.2539\n',
#  '1 5.61274 3.97264 12.3592\n',
#  '1 4.1143 3.82163 12.326\n',
#  '2 8.93751 9.16694 6.47353\n',
#  '1 8.432 9.88802 6.72745\n',
#  '1 8.48468 8.37545 6.69333\n',
#  '2 8.07164 2.22942 0.1281\n',
#  '1 8.06244 2.79115 0.9673\n',
#  '1 8.70692 2.78334 11.9344\n',
#  '2 11.7262 1.50108 1.08106\n',
#  '1 0.350097 1.67344 1.1529\n',
#  '1 11.1871 1.37275 1.9522\n',
#  '2 9.00443 7.16478 0.5284\n',
#  '1 8.52764 7.50926 12.3146\n',
#  '1 9.53634 6.99502 12.2666\n',
#  '2 1.75937 10.3409 6.76961\n',
#  '1 0.968007 10.0718 6.49787\n',
#  '1 2.45929 10.1517 6.11566\n',
#  '2 7.62241 7.64162 3.80726\n',
# ...
